# %% [markdown]
# Módulo 01: Descarga y Preparación de Datos
# ### Versión: `01_data_v1.4.4` – Fecha: 2025-10-20
# **Estado:** Producción estable
# **Autor:** W. Aguirre — *Proyecto Mini Reinanse (Sistema Cuantitativo Modular)*
#
# ---
#
# ## 📘 Descripción General
# Este módulo descarga, valida y prepara los datos históricos de precios para todos los activos bursátiles disponibles en MetaTrader 5 (CFDs de acciones US).
# Los datos se transforman en series temporales limpias y se enriquecen con indicadores técnicos y métricas de calidad para ser utilizados en los módulos posteriores de modelado, backtesting y ejecución.
#
# ---
#
# ## ⚙️ Flujo General de Proceso
# 1. **Inicialización y configuración de rutas**
# 2. **Conexión a MetaTrader 5** (verificación de cuenta y servidor)
# 3. **Generación del universo de símbolos US** (`symbol_aliases.json`)
# 4. **Descarga paralela de datos históricos**
# 5. **Cálculo de features técnicos:**
#    - Retornos (`returns`)
#    - Volatilidad 20d (`volatilidad`)
#    - Drawdown acumulado (`drawdown`)
#    - Media móvil 20d (`ma20`)
#    - Score compuesto (momentum / volatilidad)
#    - Sharpe 20d y Momentum 63d
# 6. **Validaciones automáticas:**
#    - Precios > 15 USD
#    - Mínimo 250 barras
#    - Sin huecos > 5 días
#    - Volatilidad mínima > 1e-3
# 7. **Consolidación final**
#    - `prices_df_diario.pkl`  →  Precios diarios
#    - `prices_df.pkl`  →  Último precio mensual
#
# ---
#
# ## 📊 Salidas Principales
# | Archivo | Descripción | Ubicación |
# |----------|--------------|-----------|
# | `symbol_aliases.json` | Mapeo simplificado alias ↔ ticker | `/notebooks/` |
# | `symbol_aliases_ext.json` | Mapeo extendido con exchange y path | `/notebooks/` |
# | `data/raw/*.csv` | Datos OHLC crudos por activo | `/data/raw/` |
# | `data/processed/features_estado_*.csv` | Datos procesados + features | `/data/processed/` |
# | `backtesting/prices_df_diario.pkl` | Precios diarios consolidados | `/backtesting/` |
# | `backtesting/prices_df.pkl` | Precios mensuales (último de cada mes) | `/backtesting/` |
# | `log_resumen_validacion.txt` | Log de integridad global | `/Mini reinanse/` |
#
# ---
#
# ## 🔍 Métricas de Integridad
# - Activos procesados correctamente: **≈ 97 %**
# - Motivos de descarte: `precio_bajo`, `datos_insuficientes`
# - Integridad temporal y de features > 95 %
# - Sin errores de `DatetimeIndex` ni duplicados
#
# ---
#
# ## 🧠 Mejoras de la Versión 1.4.4
# | Categoría | Mejora |
# |------------|---------|
# | **Rendimiento** | Ejecución paralela optimizada (`ThreadPoolExecutor` + `tqdm`) |
# | **Estabilidad** | Control de salida (preview limitado, sin saturar Jupyter) |
# | **Compatibilidad** | Logging UTF-8 seguro (sin errores Unicode Windows) |
# | **Validación** | Nuevas métricas de integridad y diagnóstico final |
# | **Estructura** | Separación modular en 9 celdas (config → diagnóstico) |
# | **Consolidación** | Creación de `.pkl` diarios y mensuales verificables |
#
# ---
#
# ## 🔒 Dependencias Principales
# - `MetaTrader5`
# - `pandas ≥ 1.5`
# - `numpy`
# - `tqdm`
# - `concurrent.futures`
# - `logging`
# - `os`, `json`, `datetime`
#
# ---
#
# ## ✅ Estado Final del Módulo
# | Componente | Estado |
# |-------------|--------|
# | Conexión MT5 | 🟢 Operativa |
# | Descarga de datos | 🟢 Verificada |
# | Cálculo de features | 🟢 Correcto |
# | Validación temporal | 🟢 Sin huecos |
# | Consolidación | 🟢 Completada |
# | Integridad global | 🟢 97 % OK |
#
# ---
#
# > Este notebook marca el punto de partida del pipeline cuantitativo de Mini Reinanse.
# > Los archivos generados son la base de entrada para `02_model.ipynb` (entrenamiento HMM/ML) y los módulos de backtesting y riesgo.

# %%
# 1.- Inicialización 
import re
import numpy as np
import pandas as pd

def detectar_bolsa(path: str) -> str:
    p = (path or "").lower()
    if "nasdaq" in p: return "NASDAQ"
    if "nyse" in p: return "NYSE"
    if "dow" in p: return "DOW"
    return "OTHER"

def safe_symbol_name(name: str) -> str:
    return re.sub(r'[^A-Za-z0-9\.\-_]+', '_', name).strip("_")

def alias_from_mt5_name(sym_name: str, path: str) -> str:
    m = re.search(r'\(([A-Z0-9\.\-]+)\)\s*$', sym_name)
    if m:
        return f"{m.group(1)}.US"
    last_seg = (path or sym_name).split("\\")[-1]
    last_seg = re.sub(r'[^A-Z0-9\.\-]+', '', last_seg, flags=re.I)
    if last_seg:
        return f"{last_seg}.US"
    base = re.sub(r'[#]+', '', sym_name)
    base = re.sub(r'(_i|_m|_ar|_x|\.NQ|\.NAS|\.NYSE)$', '', base, flags=re.I)
    return f"{base}.US"

def validar_huecos(index: pd.DatetimeIndex, max_gap_days=5) -> bool:
    if len(index) < 2:
        return False
    ordered = index.sort_values().asi8
    if ordered.size < 2:
        return False
    gaps = np.diff(ordered)
    max_gap = gaps.max() if gaps.size else 0
    return max_gap <= pd.Timedelta(days=max_gap_days).value

print("✅ Inicialización y configuración de rutas cargados correctamente.")
# Out:
# ✅ Inicialización y configuración de rutas cargados correctamente.

# %%
# 2.- Configuración de rutas
import MetaTrader5 as mt5
import os, json, logging, re, time
from datetime import datetime, timedelta
from collections import defaultdict, OrderedDict
from concurrent.futures import ThreadPoolExecutor, as_completed
from pathlib import Path

from hedgefund_paths import build_paths, ensure_directories, configure_logger

paths = build_paths()
BASE_DIR = paths['base']
PROJECT_DIR = paths['project']
NOTEBOOKS_DIR = paths['notebooks']
DATA_DIR = paths['data']
DATA_RAW_DIR = paths['data_raw']
DATA_PROCESSED_DIR = paths['data_processed']
ESTADO_DIR = paths['estado']
BACKTESTING_DIR = paths['backtesting']

ensure_directories([NOTEBOOKS_DIR, DATA_RAW_DIR, DATA_PROCESSED_DIR, ESTADO_DIR, BACKTESTING_DIR])

VERSION = "01_data_v1.4.4_2025-10-20"
LOG_PATH = NOTEBOOKS_DIR / "01_log_features_estado.log"
logger = configure_logger(LOG_PATH)
logger.info("Celda 1 ejecutada correctamente.")
logger.info("Directorio base: %s", PROJECT_DIR)

print("✅ Configuración de rutas creada correctamente.")
print(f"📁 Directorio base: {PROJECT_DIR}")
# Out:
# INFO - Celda 1 ejecutada correctamente.
# INFO - Directorio base: C:\Users\User\Downloads\Mini reinanse\notebooks
# ✅ Configuración de rutas creada correctamente.
# 📁 Directorio base: C:\Users\User\Downloads\Mini reinanse\notebooks

# %%
# 3.- Parámetros de operacion
DIAS_HISTORICOS = 1095
TIMEFRAME = mt5.TIMEFRAME_D1
FECHA_HASTA = datetime.now() - timedelta(days=1)
FECHA_DESDE = FECHA_HASTA - timedelta(days=DIAS_HISTORICOS)
PRECIO_MINIMO = 15
VOL_MIN_MEDIA = 1e-3
HUECO_MAX_DIAS = 5
MIN_BARRAS = 250
MAX_WORKERS = min(6, (os.cpu_count() or 6))
REINTENTOS = 2
SLEEP_ENTRE_INTENTOS = 0.5

PATH_ALIASES = os.path.join(NOTEBOOKS_DIR, "symbol_aliases.json")
PATH_ALIASES_EXT = os.path.join(NOTEBOOKS_DIR, "symbol_aliases_ext.json")

print("📡 Intentando conexión con MetaTrader 5...")
if not mt5.initialize():
    raise SystemExit(f"🛑 No se pudo conectar a MetaTrader 5: {mt5.last_error()}")
acc = mt5.account_info()
print(f"✅ Conectado a cuenta {acc.login if acc else 'N/A'} en servidor {acc.server if acc else 'N/A'}")
print(f"📆 Rango de datos: {FECHA_DESDE.date()} → {FECHA_HASTA.date()}")
# Out:
# 📡 Intentando conexión con MetaTrader 5...
# ✅ Conectado a cuenta 3000086292 en servidor Darwinex-Demo
# 📆 Rango de datos: 2022-11-17 → 2025-11-16

# %%
# 4.- Cálculo de indicadores técnicos
class FeatureCalculator:
    def __init__(self, df: pd.DataFrame):
        self.df = df.copy()

    def add_returns(self):
        self.df["returns"] = self.df["close"].pct_change()
        return self

    def add_volatility(self, windows=[20, 63]):
        for w in windows:
            self.df[f"volatilidad_{w}"] = self.df["returns"].rolling(w).std()
        return self

    def add_drawdown(self, windows=[None]):
        for w in windows:
            if w is None:
                self.df["drawdown"] = self.df["close"] / self.df["close"].cummax() - 1
            else:
                self.df[f"drawdown_{w}"] = self.df["close"] / self.df["close"].rolling(w).max() - 1
        return self

    def add_moving_averages(self, windows=[20, 50, 200]):
        for w in windows:
            self.df[f"ma{w}"] = self.df["close"].rolling(w).mean()
        return self

    def add_zscore(self, window=20):
        ma = self.df["close"].rolling(window).mean()
        std = self.df["close"].rolling(window).std()
        self.df["zscore_close"] = (self.df["close"] - ma) / (std + 1e-8)
        return self

    def add_momentum(self, period=63):
        self.df[f"mom_{period}"] = self.df["close"].pct_change(period)
        return self

    def add_score_compuesto(self, window_returns=5, window_vol=20):
        avg_return = self.df["returns"].rolling(window_returns).mean()
        vol = self.df[f"volatilidad_{window_vol}"].replace(0, np.nan).fillna(1e-8)
        self.df["score_compuesto"] = avg_return / vol
        return self

    def add_sharpe(self, window=20):
        avg_return = self.df["returns"].rolling(window).mean()
        vol = self.df[f"volatilidad_{window}"].replace(0, np.nan).fillna(1e-8)
        self.df[f"sharpe_{window}"] = avg_return / vol
        return self

    def add_atr(self, window=14):
        tr1 = self.df["high"] - self.df["low"]
        tr2 = abs(self.df["high"] - self.df["close"].shift())
        tr3 = abs(self.df["low"] - self.df["close"].shift())
        tr = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)
        self.df[f"atr_{window}"] = tr.rolling(window).mean()
        return self

    def add_rsi(self, window=14):
        delta = self.df["close"].diff()
        up = delta.clip(lower=0)
        down = -delta.clip(upper=0)
        roll_up = up.rolling(window).mean()
        roll_down = down.rolling(window).mean()
        rs = roll_up / (roll_down + 1e-8)
        self.df[f"rsi_{window}"] = 100 - (100 / (1 + rs))
        return self

    def add_alpha_rank(self):
        mom = self.df["mom_63"]
        dd = self.df["drawdown"]
        self.df["alpha_rank"] = (
            0.5 * mom.rank(pct=True) +
            0.5 * (-dd).rank(pct=True)
        )
        return self

    def compute(self):
        return self.df

def calcular_features(df: pd.DataFrame) -> pd.DataFrame:
    return (
        FeatureCalculator(df)
        .add_returns()
        .add_volatility()
        .add_drawdown()
        .add_moving_averages()
        .add_zscore()
        .add_momentum()
        .add_score_compuesto()
        .add_sharpe()
        .add_atr()
        .add_rsi()
        .add_alpha_rank()
        .compute()
    )

# %%
# 5.- Universo de acciones
US_PATH_KEY = "stocks\\us"
all_syms = [s for s in mt5.symbols_get() if (s.path or "").lower().find(US_PATH_KEY) != -1]
tradables = [s for s in all_syms if (mt5.symbol_info(s.name) and mt5.symbol_info(s.name).trade_mode == mt5.SYMBOL_TRADE_MODE_FULL)]

print(f"📚 Detectados {len(all_syms)} símbolos US, de los cuales {len(tradables)} son operables.")

# ===== Mapping =====
mapping_simple = OrderedDict()
mapping_ext = OrderedDict()
for s in tradables:
    exch = detectar_bolsa(s.path)
    alias = alias_from_mt5_name(s.name, s.path)
    ticker_real = s.name
    mapping_simple[alias] = ticker_real
    mapping_ext[alias] = {"ticker": ticker_real, "exchange": exch, "path": s.path}

with open(PATH_ALIASES, "w", encoding="utf-8") as f:
    json.dump(mapping_simple, f, indent=2)
with open(PATH_ALIASES_EXT, "w", encoding="utf-8") as f:
    json.dump(mapping_ext, f, indent=2)

print(f"✅ Archivos de mapeo generados: {len(mapping_ext)} símbolos guardados.")
print("🔹 Ejemplo:", list(mapping_simple.items())[:5])
# Out:
# 📚 Detectados 707 símbolos US, de los cuales 699 son operables.
# ✅ Archivos de mapeo generados: 699 símbolos guardados.
# 🔹 Ejemplo: [('A.US', 'A'), ('AA.US', 'AA'), ('AAP.US', 'AAP'), ('ABBV.US', 'ABBV'), ('AAL.US', 'AAL')]

# %%
# 6.- Exploracion de activos
import pandas as pd, os, json
print("🔍 Generando DataFrame con los primeros activos que se descargarán...")

df_universo = pd.DataFrame.from_dict(mapping_ext, orient="index").reset_index()
df_universo.rename(columns={"index": "alias"}, inplace=True)
df_universo = df_universo.sort_values("alias").reset_index(drop=True)

print(f"📦 Total detectados: {len(df_universo)} símbolos.")
print("🔸 Primeros 10 activos a descargar:")
display(df_universo.head(10))

PROJECT_DIR = "C:/Users/User/Downloads/Mini reinanse"
preview_path = os.path.join(PROJECT_DIR, "preview_descarga_mt5.csv")
df_universo.head(10).to_csv(preview_path, index=False, encoding="utf-8-sig")
print("Felicidades, se ha creado el archivo de vista previa (primeras 10 filas), útil para validar los datos cargados.")
print(f"✅ Vista previa guardada en: {preview_path}")
# Out:
# 🔍 Generando DataFrame con los primeros activos que se descargarán...
# 📦 Total detectados: 699 símbolos.
# 🔸 Primeros 10 activos a descargar:
#      alias ticker exchange                   path
# 0     A.US      A     NYSE       Stocks\US\NYSE\A
# 1    AA.US     AA     NYSE      Stocks\US\NYSE\AA
# 2   AAL.US    AAL   NASDAQ   Stocks\US\Nasdaq\AAL
# 3   AAP.US    AAP     NYSE     Stocks\US\NYSE\AAP
# 4  AAPL.US   AAPL      DOW     Stocks\US\DOW\AAPL
# 5  ABBV.US   ABBV     NYSE    Stocks\US\NYSE\ABBV
# 6   ABT.US    ABT     NYSE     Stocks\US\NYSE\ABT
# 7  ACHC.US   ACHC   NASDAQ  Stocks\US\Nasdaq\ACHC
# 8   ACM.US    ACM     NYSE     Stocks\US\NYSE\ACM
# 9   ACN.US    ACN     NYSE     Stocks\US\NYSE\ACN
# Felicidades, se ha creado el archivo de vista previa (primeras 10 filas), útil para validar los datos cargados.
# ✅ Vista previa guardada en: C:/Users/User/Downloads/Mini reinanse\preview_descarga_mt5.csv

# %%
# 7.- Descarga de datos de acciones
motivos_falla = defaultdict(list)
precios_consolidados = {}
activos_ok = []

# Control de preview para evitar saturar la salida
preview_counter = 0
preview_limit = 3

def descargar_barras(ticker_real: str):
    """Descarga barras desde MetaTrader 5 con reintentos automáticos."""
    rates = mt5.copy_rates_range(ticker_real, TIMEFRAME, FECHA_DESDE, FECHA_HASTA)
    if rates is not None and len(rates) > 0:
        return rates
    for _ in range(REINTENTOS):
        time.sleep(SLEEP_ENTRE_INTENTOS)
        rates = mt5.copy_rates_range(ticker_real, TIMEFRAME, FECHA_DESDE, FECHA_HASTA)
        if rates is not None and len(rates) > 0:
            return rates
    rates = mt5.copy_rates_from_pos(ticker_real, TIMEFRAME, 0, 1000)
    if rates is None or len(rates) == 0:
        logger.warning(f"Sin datos para {ticker_real} - Error {mt5.last_error()}")
    return rates


def procesar_simbolo(alias_swq: str, meta: dict):
    """Procesa un símbolo: descarga datos, calcula features y guarda CSVs."""
    global preview_counter

    ticker_real = meta["ticker"]
    if not mt5.symbol_select(ticker_real, True):
        codigo, mensaje_mt5 = mt5.last_error()
        motivo = f"no seleccionable (MT5 error {codigo}: {mensaje_mt5})"
        if 'logger' in globals():
            logger.warning("%s descartado: %s", ticker_real, motivo)
        return None, motivo

    info = mt5.symbol_info(ticker_real)
    precio = (info.last or info.bid) if info else None
    if precio is None or precio <= PRECIO_MINIMO:
        motivo = f"precio bajo (último={precio})"
        if 'logger' in globals():
            logger.warning("%s descartado: %s", ticker_real, motivo)
        return None, motivo

    rates = descargar_barras(ticker_real)
    if rates is None:
        motivo = "datos insuficientes (sin barras)"
        if 'logger' in globals():
            logger.warning("%s descartado: %s", ticker_real, motivo)
        return None, motivo
    if len(rates) < MIN_BARRAS:
        motivo = f"datos insuficientes ({len(rates)} < {MIN_BARRAS})"
        if 'logger' in globals():
            logger.warning("%s descartado: %s", ticker_real, motivo)
        return None, motivo

    df = pd.DataFrame(rates)
    df["time"] = pd.to_numeric(df["time"], errors="coerce").astype("Int64")
    df["time"] = pd.to_datetime(df["time"], unit="s", errors="coerce", utc=True).dt.tz_convert(None)
    df = df.dropna(subset=["time"])
    df.set_index("time", inplace=True)
    df = df[~df.index.duplicated(keep="last")].sort_index()

    if not validar_huecos(df.index, HUECO_MAX_DIAS):
        motivo = f"huecos temporales (> {HUECO_MAX_DIAS} días sin datos)"
        if 'logger' in globals():
            logger.warning("%s descartado: %s", ticker_real, motivo)
        return None, motivo

    df = calcular_features(df)
    df["exchange"] = meta.get("exchange", "OTHER")

    file_symbol = safe_symbol_name(alias_swq)
    raw_path = DATA_RAW_DIR / f"{file_symbol}.csv"
    proc_path = DATA_PROCESSED_DIR / f"features_estado_{file_symbol}.csv"
    df.to_csv(raw_path, index_label="time")
    logger.info(f"Datos crudos guardados en {raw_path}")
    df.to_csv(proc_path, index_label="time")
    logger.info(f"Datos procesados guardados en {proc_path}")

    if preview_counter < preview_limit:
        preview_counter += 1
        logger.info(f"📈 {alias_swq} ({ticker_real}) → {len(df)} registros OK.")
        display(df[["open", "high", "low", "close", "tick_volume"]].head(2))
        display(df[["open", "high", "low", "close", "tick_volume"]].tail(2))
    elif preview_counter == preview_limit:
        logger.info("... salida truncada para evitar sobrecarga ...")
        preview_counter += 1

    return df.copy(), None


print("⚙️ Funciones de descarga listas (versión estable).")
# Out:
# ⚙️ Funciones de descarga listas (versión estable).

# %%
df = calcular_features(df)  # ✅ Genera drawdown, mom_63, volatilidad, score, etc.
df["exchange"] = meta.get("exchange", "OTHER")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = calcular_features(df)  # ✅ Genera drawdown, mom_63, volatilidad, score, etc.
#       2 df["exchange"] = meta.get("exchange", "OTHER")
#
# NameError: name 'df' is not defined

# %%
# 8.-Ejecución paralela (versión estable con barra de progreso) =====
from tqdm import tqdm

print("🚀 Iniciando procesamiento paralelo (modo estable)...")
futuros = {}
total_activos = len(mapping_ext)

# Preparamos barra de progreso
pbar = tqdm(total=total_activos, desc="Procesando activos", ncols=100, colour="cyan")

with ThreadPoolExecutor(max_workers=MAX_WORKERS) as ex:
    for alias, meta in mapping_ext.items():
        futuros[ex.submit(procesar_simbolo, alias, meta)] = alias

for fut in as_completed(futuros):
    alias = futuros[fut]
    try:
        resultado, error = fut.result()
        if error is None:
            precios_consolidados[alias] = resultado["close"].rename(alias)
            activos_ok.append(alias)
        else:
            motivos_falla[error].append(alias)
    except Exception as e:
        err_msg = f"Excepción procesando {alias}: {str(e)}"
        logger.error(err_msg.encode("utf-8", errors="ignore").decode("utf-8", errors="ignore"))
        motivos_falla["excepción"].append(alias)
    finally:
        pbar.update(1)

pbar.close()

print("\n🏁 PROCESAMIENTO FINALIZADO")
print(f"✅ Activos descargados correctamente: {len(activos_ok)} / {total_activos}")
print(f"❌ Fallidos: {sum(len(v) for v in motivos_falla.values())}")
print("🧾 Motivos de falla (resumen):", {k: len(v) for k, v in motivos_falla.items()})
# Out:
# 🚀 Iniciando procesamiento paralelo (modo estable)...
# Procesando activos:   0%|                                                   | 0/699 [00:00<?, ?it/s]WARNING - AAL descartado: precio bajo (último=12.64)
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AA.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\A.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AAP.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ACHC.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ABBV.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ABT.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AA.US.csv
# INFO - 📈 AA.US (AA) → 750 registros OK.
#              open   high    low  close  tick_volume
# time
# 2022-11-18  47.91  48.51  46.66  47.31         3540
# 2022-11-21  45.62  46.88  44.50  46.58         3407
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_A.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AAP.US.csv
#              open   high    low  close  tick_volume
# time
# 2025-11-13  39.84  39.86  37.68  38.14         4547
# 2025-11-14  37.02  38.13  36.37  37.50         4300
# INFO - 📈 A.US (A) → 750 registros OK.
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ACHC.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ABBV.US.csv
#               open    high     low   close  tick_volume
# time
# 2022-11-18  146.61  147.47  144.05  146.07         1363
# 2022-11-21  145.00  147.09  144.22  144.52         1222
# INFO - 📈 AAP.US (AAP) → 750 registros OK.
#              open    high     low   close  tick_volume
# time
# 2025-11-13  149.3  152.02  145.95  146.68         1641
# 2025-11-14  145.7  147.89  144.72  146.87         1506
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ABT.US.csv
#               open    high     low   close  tick_volume
# time
# 2022-11-18  149.63  149.64  145.56  147.23         1643
# 2022-11-21  147.85  149.87  146.29  148.04         1777
# INFO - ... salida truncada para evitar sobrecarga ...
# INFO - ... salida truncada para evitar sobrecarga ...
# INFO - ... salida truncada para evitar sobrecarga ...
#              open   high    low  close  tick_volume
# time
# 2025-11-13  51.26  51.59  50.01  50.20         1204
# 2025-11-14  49.28  50.07  49.00  49.87          908
# WARNING - AES descartado: precio bajo (último=14.02)
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ACM.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ACM.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ACN.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ADM.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AFG.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AEP.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AFL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ACN.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AFG.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ADM.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AFL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AGCO.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AEP.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AGCO.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AIG.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AJG.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AIZ.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ADI.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AIG.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ADBE.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AJG.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ADP.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AIZ.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ADI.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ADBE.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ADP.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ADSK.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AKAM.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ADSK.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ALB.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AKAM.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ALGN.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ALK.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ALB.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ALGN.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ALK.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ALL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ALLY.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ALL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ALNY.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ALLY.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AME.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AMAT.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AMD.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ALNY.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AMED.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AMAT.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AME.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AMD.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AMG.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AMED.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AMG.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AMGN.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AMKR.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AMGN.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AMP.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AMT.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AMKR.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AN.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AMP.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AMT.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ANET.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AMZN.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AN.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ANET.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AON.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AMZN.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AOS.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AON.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\APA.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\APD.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\APH.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\APLS.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AOS.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_APA.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_APD.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_APH.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_APLS.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ARCC.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ARES.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ARCC.US.csv
# WARNING - AVTR descartado: precio bajo (último=11.13)
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ARMK.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ARW.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ARES.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ARWR.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ASH.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ARW.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ARMK.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AVY.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ARWR.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ASH.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AVY.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AWI.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AWI.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AWK.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AVGO.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AXON.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AWK.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AXTA.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AYI.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AVGO.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AXON.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AXTA.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AZO.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AYI.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AZO.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\COR.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BAC.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BAH.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_COR.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BALL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BAX.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BAC.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BALL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BAH.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BAX.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BBY.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BBY.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BC.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BDX.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BEN.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BFAM.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BILL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BDX.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BC.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BEN.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BILL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BFAM.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BIO.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BIO.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BKR.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BJ.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BK.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BLD.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BLK.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BJ.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BKR.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BK.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BLD.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BLK.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BMY.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BMY.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BR.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BRKb.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BSX.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BRO.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BURL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BR.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BRKb.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BSX.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BRO.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BURL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BWA.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BWA.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BX.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BYD.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CACI.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\C.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CABO.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BX.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_C.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CACI.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BYD.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CAG.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CABO.US.csv
# WARNING - CC descartado: precio bajo (último=11.55)
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CAG.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CAH.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CARR.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CB.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CBRE.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CARR.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CB.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CAH.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CCI.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CBRE.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CCK.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CCI.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CCL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CCK.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CE.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CF.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CCL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CFG.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CE.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CF.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CFR.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CFG.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CHD.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CFR.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CHE.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CHD.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CHWY.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CI.US.csv
# WARNING - CLF descartado: precio bajo (último=11.06)
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CHE.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CIEN.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CHWY.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CI.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CIEN.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CMA.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CMG.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CLX.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CMA.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CMG.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CMI.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CLX.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CMS.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CNC.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CMI.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CMS.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CNC.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\COF.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CNP.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\COHR.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_COF.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CNP.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\COO.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\COP.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CPAY.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_COHR.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CPAY.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_COO.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CRM.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_COP.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CRL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CRM.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CRL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CSL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CTVA.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CVNA.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CSL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CVS.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CTVA.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\D.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DAL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CVNA.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CVS.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_D.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DAL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DAY.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DAR.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DAY.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\AZTA.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DAR.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BKNG.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_AZTA.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BIIB.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BKNG.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BIIB.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BLDR.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BMRN.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BLDR.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\BRKR.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BMRN.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CACC.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CAR.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CASY.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_BRKR.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CACC.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CAR.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CDNS.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CASY.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CDW.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CDNS.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CDW.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CG.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CGNX.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CHRW.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CHDN.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CG.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CGNX.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CHRW.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CHTR.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CHDN.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CINF.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CHTR.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CMCSA.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CINF.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CME.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\COLM.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CMCSA.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\COST.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CME.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_COLM.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CPRT.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_COST.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CPRT.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CROX.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CRWD.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CSGP.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CROX.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CSX.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CTAS.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CRWD.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CSGP.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CSX.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\CTSH.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CTAS.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_CTSH.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DBX.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DDOG.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DD.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DBX.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DE.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DDOG.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DD.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DELL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DE.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DECK.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DECK.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DELL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DG.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DHI.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DGX.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DG.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DHR.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DHI.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DGX.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DLB.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DKS.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DHR.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DLB.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DKS.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DLTR.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DNLI.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DLTR.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DNLI.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DOV.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DOCU.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DOX.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DOV.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DPZ.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DOCU.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DOX.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DT.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DRI.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DPZ.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DTE.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DRI.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DT.US.csv
# WARNING - DXC descartado: precio bajo (último=12.62)
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DUK.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DTE.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DVA.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DVN.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DUK.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DVA.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\DXCM.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ECL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DVN.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_DXCM.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\EA.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ECL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\EBAY.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\EEFT.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_EA.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\EFX.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_EBAY.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_EEFT.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\EHC.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\EIX.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_EFX.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_EHC.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_EIX.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\EL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ELAN.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ELV.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_EL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\EME.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ELAN.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ELV.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\EMR.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\EMN.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_EME.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_EMR.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_EMN.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ENOV.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ENPH.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ENOV.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ENTG.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\EOG.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\EPAM.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ENPH.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ENTG.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_EOG.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\EQH.US.csv
# ...
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\TREX.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_TNL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_TPR.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_TOL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_TREX.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_TPL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\TRGP.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\TRU.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_TRGP.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\TTC.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\TSN.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\TXT.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\TWLO.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_TRU.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_TTC.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_TSN.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_TXT.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_TWLO.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\TYL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_TYL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\UBER.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\UGI.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\UAL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\UHS.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_UBER.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\UNM.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_UGI.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_UAL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_UHS.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\UNP.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_UNM.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_UNP.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\URI.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\UPS.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\USB.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\USFD.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\VAC.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_UPS.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_URI.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\VEEV.US.csv
# WARNING - VFC descartado: precio bajo (último=14.53)
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_USFD.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_USB.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_VAC.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_VEEV.US.csv
# WARNING - VYX descartado: precio bajo (último=10.59)
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\VMC.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\VLO.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\W.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\VOYA.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\VST.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_VLO.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_VMC.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\VVV.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_W.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_VST.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_VOYA.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_VVV.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WAB.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WAL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WAT.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WCC.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WAB.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WEC.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WEX.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WAL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WAT.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WCC.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WEC.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WEX.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WFC.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WH.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WHR.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WK.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WFC.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WM.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WH.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WHR.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WK.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WMB.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WM.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WMS.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WMB.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WRB.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WMS.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WSM.US.csv
# WARNING - WU descartado: precio bajo (último=8.88)
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WSO.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WRB.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WST.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WSM.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WTRG.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WSO.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WST.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\XPO.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WTRG.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\XYL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_XPO.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\YETI.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_XYL.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\YUM.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ZBH.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ZTS.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_YETI.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_YUM.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ZBH.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WWD.US.csv
# WARNING - XRAY descartado: precio bajo (último=10.45)
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ZTS.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\WYNN.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WWD.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\XEL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_WYNN.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ZD.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ZBRA.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ZG.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_XEL.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ZBRA.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ZD.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ZION.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ZG.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ZM.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ZION.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ZM.US.csv
# WARNING - SGI descartado: datos insuficientes (189 < 250)
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ZS.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\COIN.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\ZWS.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_COIN.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ZS.US.csv
# INFO - Datos crudos guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\raw\XYZ.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_ZWS.US.csv
# INFO - Datos procesados guardados en C:\Users\User\Downloads\Mini reinanse\notebooks\data\processed\features_estado_XYZ.US.csv
# Procesando activos: 100%|█████████████████████████████████████████| 699/699 [01:55<00:00,  6.04it/s]
# 🏁 PROCESAMIENTO FINALIZADO
# ✅ Activos descargados correctamente: 675 / 699
# ❌ Fallidos: 24
# 🧾 Motivos de falla (resumen): {'precio bajo (último=11.13)': 1, 'precio bajo (último=13.56)': 1, 'precio bajo (último=10.59)': 1, 'datos insuficientes (189 < 250)': 1, 'precio bajo (último=13.38)': 1, 'precio bajo (último=14.53)': 1, 'precio bajo (último=14.75)': 1, 'precio bajo (último=11.55)': 1, 'precio bajo (último=14.02)': 1, 'precio bajo (último=10.79)': 1, 'precio bajo (último=5.62)': 1, 'precio bajo (último=14.27)': 1, 'precio bajo (último=8.46)': 1, 'precio bajo (último=11.06)': 1, 'precio bajo (último=3.44)': 1, 'precio bajo (último=8.29)': 1, 'precio bajo (último=8.93)': 1, 'precio bajo (último=10.45)': 1, 'datos insuficientes (143 < 250)': 1, 'precio bajo (último=12.62)': 1, 'precio bajo (último=12.99)': 1, 'precio bajo (último=8.88)': 1, 'precio bajo (último=9.3)': 1, 'precio bajo (último=12.64)': 1}

# %%
# 9.- Consolidación de precios descargados =====
print("📦 Consolidando precios descargados...")

if activos_ok:
    df_final = pd.DataFrame(precios_consolidados)
    df_final.index = pd.to_datetime(df_final.index, errors="coerce")
    df_final = df_final[~df_final.index.isna()]
    df_final.index.name = "time"

    # Guardar precios diarios
    diario_path = BACKTESTING_DIR / "prices_df_diario.pkl"
    df_final.to_pickle(diario_path)

    # Versión mensual (último valor de cada mes)
    df_final_mensual = df_final.resample("M").last()
    mensual_path = BACKTESTING_DIR / "prices_df.pkl"
    df_final_mensual.to_pickle(mensual_path)

    print(f"✅ Consolidación completa ({len(df_final.columns)} activos válidos).")
    print(f"🗓️ Fechas: {df_final.index.min().date()} → {df_final.index.max().date()}")
    print(f"💾 Guardado en:\n  - {diario_path}\n  - {mensual_path}")

    # Preview visual
    print("\n🔍 Últimos 5 días de precios (primeras 5 columnas):")
    display(df_final.tail(5).iloc[:, :5])
else:
    print("⚠️ No hay activos válidos para consolidar.")
# Out:
# 📦 Consolidando precios descargados...
# ✅ Consolidación completa (675 activos válidos).
# 🗓️ Fechas: 2022-11-18 → 2025-11-14
# 💾 Guardado en:
#   - C:\Users\User\Downloads\Mini reinanse\notebooks\backtesting\prices_df_diario.pkl
#   - C:\Users\User\Downloads\Mini reinanse\notebooks\backtesting\prices_df.pkl
#
# 🔍 Últimos 5 días de precios (primeras 5 columnas):
#             PEN.US  HUM.US  ACM.US  ALGN.US  PEGA.US
# time
# 2025-11-10  270.41  237.60  130.49   137.90    59.60
# 2025-11-11  278.77  242.97  131.45   144.14    59.91
# 2025-11-12  279.48  240.60  132.26   141.49    59.02
# 2025-11-13  278.47  236.16  133.70   139.24    56.68
# 2025-11-14  279.49  236.27  133.51   137.15    56.70

# %%
# 10.- Estadísticas
total = len(mapping_simple)
exitosos = len(activos_ok)
fallidos = total - exitosos
integridad_pct = round(100 * exitosos / total, 2) if total > 0 else 0.0

por_bolsa = defaultdict(int)
for a in activos_ok:
    por_bolsa[mapping_ext[a]["exchange"]] += 1

print("\n📊 RESUMEN FINAL")
print(f"🧾 Versión: {VERSION}")
print(f"✅ OK: {exitosos} / {total} ({integridad_pct:.2f}%)")
for motivo, lista in motivos_falla.items():
    print(f"   - {motivo}: {len(lista)} activos.")
print("🏷️ Distribución por bolsa:", dict(por_bolsa))

mt5.shutdown()
print("📴 MetaTrader 5 desconectado correctamente.")
# Out:
# 📊 RESUMEN FINAL
# 🧾 Versión: 01_data_v1.4.4_2025-10-20
# ✅ OK: 675 / 699 (96.57%)
#    - precio bajo (último=11.13): 1 activos.
#    - precio bajo (último=13.56): 1 activos.
#    - precio bajo (último=10.59): 1 activos.
#    - datos insuficientes (189 < 250): 1 activos.
#    - precio bajo (último=13.38): 1 activos.
#    - precio bajo (último=14.53): 1 activos.
#    - precio bajo (último=14.75): 1 activos.
#    - precio bajo (último=11.55): 1 activos.
#    - precio bajo (último=14.02): 1 activos.
#    - precio bajo (último=10.79): 1 activos.
#    - precio bajo (último=5.62): 1 activos.
#    - precio bajo (último=14.27): 1 activos.
#    - precio bajo (último=8.46): 1 activos.
#    - precio bajo (último=11.06): 1 activos.
#    - precio bajo (último=3.44): 1 activos.
#    - precio bajo (último=8.29): 1 activos.
#    - precio bajo (último=8.93): 1 activos.
#    - precio bajo (último=10.45): 1 activos.
#    - datos insuficientes (143 < 250): 1 activos.
#    - precio bajo (último=12.62): 1 activos.
#    - precio bajo (último=12.99): 1 activos.
#    - precio bajo (último=8.88): 1 activos.
#    - precio bajo (último=9.3): 1 activos.
#    - precio bajo (último=12.64): 1 activos.
# 🏷️ Distribución por bolsa: {'NYSE': 433, 'NASDAQ': 213, 'DOW': 29}
# 📴 MetaTrader 5 desconectado correctamente.

# %%
# 11.- DIAGNÓSTICO DE INTEGRIDAD DE FEATURES (versión robusta) ===
import pandas as pd

estado_dir = ESTADO_DIR
archivos = sorted(estado_dir.glob('*.csv'))

resumen = []

print('🧪 Iniciando diagnóstico de integridad de features...')
logger.info('Iniciando diagnóstico de integridad de features en %s', estado_dir)

for file in archivos:
    try:
        df = pd.read_csv(file)
        total_rows = len(df)
        valid_cols = df.notna().mean() * 100
        integridad_media = round(valid_cols.mean(), 2)
        simbolo = file.stem.replace('features_estado_', '')
        resumen.append((simbolo, total_rows, integridad_media))
    except Exception as e:
        simbolo = file.stem.replace('features_estado_', '')
        resumen.append((simbolo, 0, 0))
        logger.exception('❌ Error leyendo %s', file)

df_resumen = pd.DataFrame(resumen, columns=['Símbolo', 'Filas', 'Integridad'])
print('🧾 Columnas del resumen:', df_resumen.columns.tolist())

df_resumen = df_resumen.sort_values('Integridad', ascending=False).reset_index(drop=True)
display(df_resumen.head(10))
print('✅ Diagnóstico completado.')
# Out:
# INFO - Iniciando diagnóstico de integridad de features en C:\Users\User\Downloads\Mini reinanse\notebooks\data\estado
# 🧪 Iniciando diagnóstico de integridad de features...
# 🧾 Columnas del resumen: ['Símbolo', 'Filas', 'Integridad']
#           Símbolo  Filas  Integridad
# 0     estado_A.US    750       99.96
# 1  estado_OLED.US    743       99.96
# 2  estado_NWSA.US    743       99.96
# 3  estado_NXST.US    743       99.96
# 4   estado_NYT.US    743       99.96
# 5    estado_OC.US    743       99.96
# 6  estado_ODFL.US    743       99.96
# 7   estado_OGE.US    743       99.96
# 8   estado_OKE.US    743       99.96
# 9  estado_OKTA.US    743       99.96
# ✅ Diagnóstico completado.

# %%
# 12.- EXPORTAR ARCHIVOS estado_<symbol>.csv =====
print("💾 Exportando archivos estado_<symbol>.csv a la carpeta /estado...")

exportados = 0

for alias in activos_ok:
    try:
        # Cargar features procesados
        file_symbol = safe_symbol_name(alias)
        proc_path = os.path.join(DATA_PROCESSED_DIR, f"features_estado_{file_symbol}.csv")
        df = pd.read_csv(proc_path, parse_dates=["time"])
        df.set_index("time", inplace=True)

        # Renombrar columnas a lo que espera el modelo
        df_final = pd.DataFrame()
        df_final["retornos"] = df["returns"]
        df_final["equity"] = df["close"]  # Usamos 'close' como proxy para equity

        # Exportar archivo
        output_path = os.path.join(ESTADO_DIR, f"estado_{alias}.csv")
        df_final.to_csv(output_path, index=True)
        print("Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.")
        exportados += 1
    except Exception as e:
        print(f"❌ Error al exportar {alias}: {e}")

print(f"✅ Archivos exportados correctamente: {exportados} / {len(activos_ok)}")
# Out:
# 💾 Exportando archivos estado_<symbol>.csv a la carpeta /estado...
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# ...
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# Felicidades, se ha creado el archivo final exportado con índice, lo cual permite conservar la referencia temporal o identificador único para futuros análisis.
# ✅ Archivos exportados correctamente: 675 / 675
